# %% [markdown]
# # Project Euler 9
#
# A Pythagorean triplet is a set of three natural numbers, $a \lt b \lt c$, for which,
# $$a^2 + b^2 = c^2.$$
# For example, $3^2 + 4^2 = 9 + 16 = 25 = 5^2$.
# There exists exactly one Pythagorean triplet for which $a + b + c = 1000$.<br>Find the product $abc$.

# %%
tuples =: (1001 1001 1001 #: i. 1001^3)

# %%
example =: 3 4 5
< ((((0 { example)^2) + ((1 { example )^2)) = (2 { example)^2) , (((0 { example) + (1 { example ) + (2 { example)) = 12)

# %%
checkTriplet =: ((*:@{.@]) + *:@({.@}.)@]) = *:@({:@])

# %%
checkAddition =: 1000 = +/

# %%
pythagorans =: ((checkTriplet"1 tuples) # tuples) 
(checkAddition"1 pythagorans) # pythagorans
# Out:
#   0 500 500
# 200 375 425
# 375 200 425
# 500   0 500

# %%
*/ 200 375 425
